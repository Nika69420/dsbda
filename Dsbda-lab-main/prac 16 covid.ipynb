# %%
import pandas as pd
import scipy.stats as stats

# %%
df=pd.read_csv('16. covid_vaccine_statewise.csv')
df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
# ...

# %%
df.head(400)
# Out:
#      Updated On                        State  Total Doses Administered  \
# 0    16/01/2021                        India                   48276.0
# 1    17/01/2021                        India                   58604.0
# 2    18/01/2021                        India                   99449.0
# 3    19/01/2021                        India                  195525.0
# 4    20/01/2021                        India                  251280.0
# ..          ...                          ...                       ...
# 395  18/07/2021  Andaman and Nicobar Islands                  258110.0
# 396  19/07/2021  Andaman and Nicobar Islands                  261259.0
# 397  20/07/2021  Andaman and Nicobar Islands                  265699.0
# 398  21/07/2021  Andaman and Nicobar Islands                  265754.0
# 399  22/07/2021  Andaman and Nicobar Islands                  270664.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
df['State'].unique()
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df2=df.groupby(df['State']).sum()
df2['First Dose Administered']
# Out:
# C:\Users\pushp\AppData\Local\Temp\ipykernel_21856\3230184083.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2=df.groupby(df['State']).sum()
# State
# Andaman and Nicobar Islands                 1.642585e+07
# Andhra Pradesh                              1.232861e+09
# Arunachal Pradesh                           4.900498e+07
# Assam                                       5.856002e+08
# Bihar                                       1.470503e+09
# Chandigarh                                  4.470310e+07
# Chhattisgarh                                7.960029e+08
# Dadra and Nagar Haveli and Daman and Diu    3.359506e+07
# Delhi                                       6.243395e+08
# Goa                                         7.599137e+07
# Gujarat                                     2.131646e+09
# ...

# %%
df3=df.groupby(df['State']).sum()
df3['Second Dose Administered']
# Out:
# C:\Users\pushp\AppData\Local\Temp\ipykernel_21856\2440037716.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3=df.groupby(df['State']).sum()
# State
# Andaman and Nicobar Islands                 4.118554e+06
# Andhra Pradesh                              3.588176e+08
# Arunachal Pradesh                           1.193232e+07
# Assam                                       1.307888e+08
# Bihar                                       2.707906e+08
# Chandigarh                                  1.159374e+07
# Chhattisgarh                                1.721204e+08
# Dadra and Nagar Haveli and Daman and Diu    4.594416e+06
# Delhi                                       1.882189e+08
# Goa                                         1.619817e+07
# Gujarat                                     6.004184e+08
# ...

# %%
df4=df['Male(Individuals Vaccinated)'].sum()
df4
# Out:
# 7138698858.0

# %%
df5=df['Female(Individuals Vaccinated)'].sum()
df5
# Out:
# 6321628736.0
